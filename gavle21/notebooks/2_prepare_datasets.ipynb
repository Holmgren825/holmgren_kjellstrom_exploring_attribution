# %% [markdown]
# # Prepare datasets
# In this notebook we will prepare cubes of the different datasets used in the project.

# %%
import iris.plot as iplt
from attribution.config import init_config
from attribution.preprocessing import (
    prepare_cordex_cube,
    prepare_eobs_cube,
    prepare_era5_cube,
    prepare_gridclim_cube,
    prepare_pthbv_cube
)
from cartopy import crs as ccrs
from dask.distributed import Client
import proplot as pplt
# Out:
# /home/sm_erhol/dev/attribution/attribution/bootstrap.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
client = Client()

# %% [markdown]
# Each attribution project should have a `config.yml` in its root directory.
# We can load in the the configuration using `init_config`

# %%
CFG = init_config()

# %% [markdown]
# This contains the paths where to find input data, and later store results.
# Most functions will read from this automatically, but  it is also possible to pass custom arguments, overriding the configuration.

# %%
CFG
# Out:
# {'paths': {'project_folder': '/nobackup/rossby27/users/sm_erhol/station_attribution_article/gavle2021',
#   'data': {'gridclim': '/nobackup/smhid17/proj/sik/SMHIGridClim_NORDIC-11/v0.9/netcdf/day/',
#    'pthbv': '/nobackup/rossby27/users/roadmin/data/pthbv/yearly/',
#    'eobs': '/home/rossby/imports/obs/EOBS/EOBS24-0e/EUR-10/remap/EUR-11/day/',
#    'era5': '/home/rossby/imports/obs/ECMWF/ERA5/remap/EUR-11/day/',
#    'cordex': '/nobackup/rossby21/sm_stran/Klimatfabrik/MidasOut/',
#    's-lens': '/nobackup/rossby22/rossby/joint_exp/large_ensemble/cmorized/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3/historical/'},
#   'shapefile': '/home/sm_erhol/data/ne_10_admin_0_countries/ne_10m_admin_0_countries.shp'},
#  'project_name': 'gavle2021',
#  'filenames': {'pthbv': 'PTHBV_day',
#   'gridclim': 'SMHIGridClim_day',
#   'eobs': 'EOBS_day',
#   'era5': 'era5_day',
#   'cordex': 'CORDEX-ENS_rcp85_day',
#   's-lens': 's-lens_day'},
#  'epsg': 3006,
#  'variable': ['pr'],
#  'index_name': ['rx1day'],
#  'partial_dates': {'low': {'year': 1989},
#   'high': {'year': 2018, 'month': 12, 'day': 31}},
#  'season': False,
#  'roi_extent': {'north': 63.0, 'south': 59.0, 'east': 19.5, 'west': 13.5}}

# %% [markdown]
# The variable that will be loaded is also defined in the configuration.
# Depending on the project this can be one or more variables.
# In the case the project is configured with more than one variable, one has to be selected and subsequently passed to the difference `prepare_*` functions.

# %%
# Here we have two variables.
CFG["variable"]
# Out:
# ['pr']

# %%
# Select the first one.
variable = CFG["variable"][0]
print(variable)
# Out:
# pr

# %% [markdown]
# <div class="alert alert-info"><b>To prepare all datasets, this entire notebook should be run once for each variable in CFG.</b></div>

# %% [markdown]
# ## Prepare GridClim
# We start by preparing the GridClim dataset.
# If the paths in `config.yml` are defined correctly this is as simple as calling `prepare_gridclim_cube`.
# This will prepare an `iris.Cube` of the entire dataset, and mask the data with a combination of an outline of Sweden and a region of interest.
# This functionality is the same for all `prepare_*_cube` functions.

# %%
# We chose to return a cube to make sure that it worked.
cube = prepare_gridclim_cube(variable=variable, return_cube=True)
# Out:
# Loading GridClim
# Realising cube, see progression in dask UI
# Saving cube
# Finished

# %% [markdown]
# We can inspect the cube

# %% [markdown]
# and plot it to make sure that we actually selected the region we are interested in

# %%
fig, ax = pplt.subplots(
    figwidth="7.5cm", projection=ccrs.epsg(3006)
)
# Just a random day in the dataset.
iplt.pcolormesh(cube[900, :, :], axes=ax[0])
ax.format(
    coast=True,
    borders=True,
    reso="hi",
)
# Out:
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:406: UserWarning: The `map_projection` keyword argument is deprecated, use `projection` to instantiate a GeoAxes instead.
#   warnings.warn("The `map_projection` keyword argument is "
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/iris/coords.py:2047: UserWarning: Coordinate 'grid_longitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/iris/coords.py:2047: UserWarning: Coordinate 'grid_latitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# Figure(nrows=1, ncols=1, figwidth=2.95)

# %% [markdown]
# ## Prepare PTHBV

# %%
pt_cube = prepare_pthbv_cube(variable=variable, partial_dates=False, return_cube=True)
# Out:
# Loading PTHBV
# Realising cube, see progression in dask UI
# Saving cube
# Finished

# %% [markdown]
# ## Prepare EOBS
# We do the same thing for the EOBS dataset.

# %%
cube = prepare_eobs_cube(variable=variable, return_cube=True)
# Out:
# Loading GridClim
# Loading EOBS
# Extracting domain
# Extracting timespan
# Realising cube, see progression in dask UI
# Saving cube
# Finished

# %%
# Again, we make sure that it selected the region we want.
iplt.pcolormesh(cube[500, :, :]);
# Out:
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/iris/coords.py:2047: UserWarning: Coordinate 'grid_longitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/iris/coords.py:2047: UserWarning: Coordinate 'grid_latitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(

# %% [markdown]
# ## Prepare ERA5
# Same thing for the ERA5 dataset.

# %%
era_cube = prepare_era5_cube(variable=variable, return_cube=True)
# Out:
# Loading GridClim
# Loading ERA5
# Extracting domain
# Extracting timespan
# Realising cube, see progression in dask UI
# Saving cube
# Finished

# %% [markdown]
# ## Prepare CORDEX
# Prepare the CORDEX dataset.

# %% [markdown]
# <div class="alert alert-warning"><b>In the case of memory issues processing the following dataset, try restarting the dask client.</b></div>

# %%
cube = prepare_cordex_cube(variable=variable, return_cube=True)
# Out:
# Loading GridClim
# Loading the CORDEX ensemble
# Extracting timespan
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting coordinates.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting coordinates.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting calendar.
# Converting coordinates.
# Converting coordinates.
# Converting coordinates.
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/iris/_lazy_data.py:303: PerformanceWarning: Increasing number of chunks by factor of 13
#   result = da.stack(list(stack))
# Realising cube, see progression in dask UI
# Saving cube
# Finished

# %% [markdown]
# ## Prepare S-Lens

# %% [markdown]
# <div class="alert alert-warning"><b>In the case of memory issues processing the following dataset, try restarting the dask client.</b></div>

# %%
cube = prepare_slens_cube(variable=variable, return_cube=True)
# Out:
# Loading S-Lens ensemble members
# Ens. chunk:   0%|          | 0/5 [00:00<?, ?it/s]
# Chunk member:   0%|          | 0/10 [00:00<?, ?it/s]
# Chunk member:   0%|          | 0/10 [00:00<?, ?it/s]
# Chunk member:   0%|          | 0/10 [00:00<?, ?it/s]
# Chunk member:   0%|          | 0/10 [00:00<?, ?it/s]
# Chunk member:   0%|          | 0/10 [00:00<?, ?it/s]
# Concatenating chunks
# Realising cube, see progression in dask UI
# /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/client.py:3095: UserWarning: Sending large graph of size 2.01 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2023-04-19 09:42:56,464 - distributed.protocol.core - CRITICAL - Failed to deserialize
# Traceback (most recent call last):
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/protocol/core.py", line 158, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
# ValueError: 2157187929 exceeds max_bin_len(2147483647)
# 2023-04-19 09:42:56,489 - distributed.core - ERROR - Exception while handling op register-client
# Traceback (most recent call last):
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/scheduler.py", line 5374, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/core.py", line 884, in handle_stream
#     msgs = await comm.read()
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/comm/tcp.py", line 254, in read
#     msg = await from_frames(
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/comm/utils.py", line 100, in from_frames
#     res = _from_frames()
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/comm/utils.py", line 83, in _from_frames
#     return protocol.loads(
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/protocol/core.py", line 158, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
# ValueError: 2157187929 exceeds max_bin_len(2147483647)
# Task exception was never retrieved
# future: <Task finished name='Task-309' coro=<Server._handle_comm() done, defined at /home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/core.py:737> exception=ValueError('2157187929 exceeds max_bin_len(2147483647)')>
# Traceback (most recent call last):
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/core.py", line 831, in _handle_comm
#     result = await result
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/scheduler.py", line 5374, in add_client
#     await self.handle_stream(comm=comm, extra={"client": client})
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/core.py", line 884, in handle_stream
#     msgs = await comm.read()
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/comm/tcp.py", line 254, in read
#     msg = await from_frames(
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/comm/utils.py", line 100, in from_frames
#     res = _from_frames()
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/comm/utils.py", line 83, in _from_frames
#     return protocol.loads(
#   File "/home/sm_erhol/.conda/envs/erhol/lib/python3.10/site-packages/distributed/protocol/core.py", line 158, in loads
#     return msgpack.loads(
#   File "msgpack/_unpacker.pyx", line 194, in msgpack._cmsgpack.unpackb
# ValueError: 2157187929 exceeds max_bin_len(2147483647)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 cube = prepare_slens_cube(variable=variable, return_cube=True)
#
# File ~/dev/attribution/attribution/preprocessing.py:974, in prepare_slens_cube(path, filename, variable, project_path, shapefile, partial_dates, roi_points, return_cube)
#     972 print("Realising cube, see progression in dask UI")
#     973 # Realising the cube data before saving.
# --> 974 cube.data
#     975 print("Saving cube")
#     976 # Where to store the file
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/iris/cube.py:2407, in Cube.data(self)
#    2374 @property
#    2375 def data(self):
#    2376     """
#    2377     The :class:`numpy.ndarray` representing the multi-dimensional data of
#    2378     the cube.
#    (...)
#    2405
#    2406     """
# -> 2407     return self._data_manager.data
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/iris/_data_manager.py:206, in DataManager.data(self)
#     203 if self.has_lazy_data():
#     204     try:
#     205         # Realise the lazy data.
# --> 206         result = as_concrete_data(self._lazy_array)
#     207         # Assign the realised result.
#     208         self._real_array = result
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/iris/_lazy_data.py:278, in as_concrete_data(data)
#     261 """
#     262 Return the actual content of a lazy array, as a numpy array.
#     263 If the input data is a NumPy `ndarray` or masked array, return it
#    (...)
#     275
#     276 """
#     277 if is_lazy_data(data):
# --> 278     (data,) = _co_realise_lazy_arrays([data])
#     280 return data
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/iris/_lazy_data.py:241, in _co_realise_lazy_arrays(arrays)
#     226 def _co_realise_lazy_arrays(arrays):
#     227     """
#     228     Compute multiple lazy arrays and return a list of real values.
#     229
#    (...)
#     239
#     240     """
# --> 241     computed_arrays = da.compute(*arrays)
#     242     results = []
#     243     for lazy_in, real_out in zip(arrays, computed_arrays):
#     244         # Ensure we always have arrays.
#     245         # Note : in some cases dask (and numpy) will return a scalar
#     246         # numpy.int/numpy.float object rather than an ndarray.
#     247         # Recorded in https://github.com/dask/dask/issues/2111.
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/distributed/client.py:3213, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3211         should_rejoin = False
#    3212 try:
# -> 3213     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3214 finally:
#    3215     for f in futures.values():
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/distributed/client.py:2348, in Client.gather(self, futures, errors, direct, asynchronous)
#    2346 else:
#    2347     local_worker = None
# -> 2348 return self.sync(
#    2349     self._gather,
#    2350     futures,
#    2351     errors=errors,
#    2352     direct=direct,
#    2353     local_worker=local_worker,
#    2354     asynchronous=asynchronous,
#    2355 )
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/distributed/utils.py:349, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     347     return future
#     348 else:
# --> 349     return sync(
#     350         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     351     )
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/distributed/utils.py:416, in sync(loop, func, callback_timeout, *args, **kwargs)
#     414 if error:
#     415     typ, exc, tb = error
# --> 416     raise exc.with_traceback(tb)
#     417 else:
#     418     return result
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/distributed/utils.py:389, in sync.<locals>.f()
#     387         future = wait_for(future, callback_timeout)
#     388     future = asyncio.ensure_future(future)
# --> 389     result = yield future
#     390 except Exception:
#     391     error = sys.exc_info()
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/tornado/gen.py:767, in Runner.run(self)
#     765 try:
#     766     try:
# --> 767         value = future.result()
#     768     except Exception as e:
#     769         # Save the exception for later. It's important that
#     770         # gen.throw() not be called inside this try/except block
#     771         # because that makes sys.exc_info behave unexpectedly.
#     772         exc: Optional[Exception] = e
#
# File ~/.conda/envs/erhol/lib/python3.10/site-packages/distributed/client.py:2212, in Client._gather(self, futures, errors, direct, local_worker)
#    2210     else:
#    2211         raise exception.with_traceback(traceback)
# -> 2212     raise exc
#    2213 if errors == "skip":
#    2214     bad_keys.add(key)
#
# CancelledError: ('concatenate-8dd44cf8fb1d94f0c1c3a2af85a11f42', 6, 13, 0, 0)

# %%
client.shutdown()

# %% [markdown]
# ## Next steps
# [Validation](./3_validation.ipynb)
#
# [Attribution](./4_attribution.ipynb)
